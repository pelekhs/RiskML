# %%
import pandas as pd
import os
from dotenv import load_dotenv
from verispy import VERIS
from mlxtend.frequent_patterns import association_rules, fpgrowth

# Environment variables
load_dotenv() 

JSON_DIR = os.environ.get('JSON_DIR')

CSV_DIR = os.path.join("..", os.environ.get('CSV_DIR'))

VERIS_DF = os.environ.get('BOOLEAN_CSV_NAME')

VERIS_DF_URL = os.environ.get('BOOLEAN_CSV_URL')

# %%
def load_dataset(csv_dir=CSV_DIR,
                 veris_df_csv=VERIS_DF, 
                 nrows=None):
    """ 
    Loads veris_df type csv (boolean VCDB dataset) from disk as a 
    Pandas DataFrame.

    Parameters
    ---------- 
        csv_dir: str / path
            The path to read the csv from
        
        veris_df_csv: str
            The name of the csv file

    Returns
    ---------- 
    DataFrame
        The loaded veris_df dataset as Pandas DataFrame  

    """    
    veris_df = pd.read_csv(os.path.join(csv_dir, veris_df_csv),
                           index_col=0,
                           low_memory=False,
                           nrows=nrows)
    
    return veris_df

enemies = load_dataset()
enemies.head()
# Out:
#    action.Environmental  action.Error  action.Hacking  action.Malware  \
# 0                 False         False            True           False
# 1                 False         False           False           False
# 2                 False          True           False           False
# 3                 False         False           False           False
# 4                 False         False            True           False
#
#    action.Misuse  action.Physical  action.Social  action.Unknown  \
# 0          False            False          False           False
# 1           True            False          False           False
# 2          False            False          False           False
# 3          False             True          False           False
# 4          False            False          False           False
#
#   action.environmental.notes  action.environmental.variety.Deterioration  ...  \
# 0                        NaN                                       False  ...
# 1                        NaN                                       False  ...
# 2                        NaN                                       False  ...
# 3                        NaN                                       False  ...
# 4                        NaN                                       False  ...
#
#    victim.revenue.iso_currency_code.YER  victim.revenue.iso_currency_code.ZAR  \
# 0                                 False                                 False
# 1                                 False                                 False
# 2                                 False                                 False
# 3                                 False                                 False
# 4                                 False                                 False
#
#    victim.revenue.iso_currency_code.ZEC  victim.revenue.iso_currency_code.ZMK  \
# 0                                 False                                 False
# 1                                 False                                 False
# 2                                 False                                 False
# 3                                 False                                 False
# 4                                 False                                 False
#
#    victim.revenue.iso_currency_code.ZWD  victim.secondary.amount  \
# 0                                 False                      NaN
# 1                                 False                      NaN
# 2                                 False                      NaN
# 3                                 False                      NaN
# 4                                 False                      NaN
#
#    victim.secondary.notes  victim.secondary.victim_id  victim.state  \
# 0                     NaN                         NaN            PA
# 1                     NaN                         NaN         US-CA
# 2                     NaN                         NaN            VA
# 3                     NaN                         NaN           NaN
# 4                     NaN                         NaN           NaN
#
#                    victim.victim_id
# 0         Centerville Clinics Inc.
# 1                         Taco Bell
# 2     American Diabetes Association
# 3  South Walkerville Medical Centre
# 4             Netfleet Domain Names
#
# [5 rows x 2430 columns]

# %%
enemies = enemies[enemies['timeline.incident.year']>=2000]
ext = [col for col in enemies.columns if 'actor.external.country.' in col]
vict = [col for col in enemies.columns if 'victim.country.' in col]
enemies =  enemies[ext+vict]

# Building the model 
frq_items = fpgrowth(enemies, min_support = 0.002, use_colnames = True) 
# Collecting the inferred rules inside the enemies dataframe 
rules_countries = association_rules(frq_items, metric ="lift",\
                                    min_threshold = 1) 
rules_countries = rules_countries.sort_values(['confidence', 'lift'],\
                                              ascending =[False, False])

## Mainly US <-> US
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/VERIS/venv/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'timeline.incident.year'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-7e5b5f6d2b9a> in <module>
# ----> 1 enemies = enemies[enemies['timeline.incident.year']>=2000]
#       2 ext = [col for col in enemies.columns if 'actor.external.country.' in col]
#       3 vict = [col for col in enemies.columns if 'victim.country.' in col]
#       4 enemies =  enemies[ext+vict]
#       5
#
# ~/opt/VERIS/venv/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~/opt/VERIS/venv/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'timeline.incident.year'

# %%
## Korea south -> north = 0
korea_south_north = enemies[enemies['actor.external.country.KR']==True]
korea_south_north = korea_south_north[korea_south_north['victim.country.KP']\
                                      ==True]

## Korea north to south = 18 incidents 
korea_north_south = enemies[enemies['actor.external.country.KP']==True]
korea_north_south = korea_north_south[korea_north_south['victim.country.KR']==True]

rules_countries.to_csv("usual_suspects.csv", index=False)

# %%
korea_soy
# Out:
# Empty DataFrame
# Columns: [actor.external.country.AD, actor.external.country.AE, actor.external.country.AF, actor.external.country.AG, actor.external.country.AI, actor.external.country.AL, actor.external.country.AM, actor.external.country.AO, actor.external.country.AQ, actor.external.country.AR, actor.external.country.AS, actor.external.country.AT, actor.external.country.AU, actor.external.country.AW, actor.external.country.AX, actor.external.country.AZ, actor.external.country.BA, actor.external.country.BB, actor.external.country.BD, actor.external.country.BE, actor.external.country.BF, actor.external.country.BG, actor.external.country.BH, actor.external.country.BI, actor.external.country.BJ, actor.external.country.BL, actor.external.country.BM, actor.external.country.BN, actor.external.country.BO, actor.external.country.BQ, actor.external.country.BR, actor.external.country.BS, actor.external.country.BT, actor.external.country.BV, actor.external.country.BW, actor.external.country.BY, actor.external.country.BZ, actor.external.country.CA, actor.external.country.CC, actor.external.country.CD, actor.external.country.CF, actor.external.country.CG, actor.external.country.CH, actor.external.country.CI, actor.external.country.CK, actor.external.country.CL, actor.external.country.CM, actor.external.country.CN, actor.external.country.CO, actor.external.country.CR, actor.external.country.CU, actor.external.country.CV, actor.external.country.CW, actor.external.country.CX, actor.external.country.CY, actor.external.country.CZ, actor.external.country.DE, actor.external.country.DJ, actor.external.country.DK, actor.external.country.DM, actor.external.country.DO, actor.external.country.DZ, actor.external.country.EC, actor.external.country.EE, actor.external.country.EG, actor.external.country.EH, actor.external.country.ER, actor.external.country.ES, actor.external.country.ET, actor.external.country.FI, actor.external.country.FJ, actor.external.country.FK, actor.external.country.FM, actor.external.country.FO, actor.external.country.FR, actor.external.country.GA, actor.external.country.GB, actor.external.country.GD, actor.external.country.GE, actor.external.country.GF, actor.external.country.GG, actor.external.country.GH, actor.external.country.GI, actor.external.country.GL, actor.external.country.GM, actor.external.country.GN, actor.external.country.GP, actor.external.country.GQ, actor.external.country.GR, actor.external.country.GS, actor.external.country.GT, actor.external.country.GU, actor.external.country.GW, actor.external.country.GY, actor.external.country.HK, actor.external.country.HM, actor.external.country.HN, actor.external.country.HR, actor.external.country.HT, actor.external.country.HU, ...]
# Index: []
#
# [0 rows x 504 columns]
